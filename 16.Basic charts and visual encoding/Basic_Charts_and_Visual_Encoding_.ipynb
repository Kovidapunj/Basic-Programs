# %% [markdown]
# <a href="https://colab.research.google.com/github/Kovidapunj/Exploratory-data-analysis-using-python/blob/main/Copy_of_Basic_Charts_and_Visual_Encoding_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment 16 (Basic Charts and Visual Encoding)
# ## Name : Kovida Punj
# ## PRN : 25070123063
# ## Batch : E&TC - A3
# ## Date : 8th April 2026

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = {
    'Days' : ['Mon','Tue','Wed','Thu','Fri'],
    'Study_Hours' : [2,3,6,1,3.5],
    'Marks' : [93,60,67,70,85],
    'Attendance': [60,70,65,80,75],
    'Assignments_Completed' : [1,2,1,3,2]

}
df = pd.DataFrame(data)
df
# Out:
#   Days  Study_Hours  Marks  Attendance  Assignments_Completed
# 0  Mon          2.0     93          60                      1
# 1  Tue          3.0     60          70                      2
# 2  Wed          6.0     67          65                      1
# 3  Thu          1.0     70          80                      3
# 4  Fri          3.5     85          75                      2

# %%
# 1. Line Chart (Trend)

plt.plot(df['Days'],df['Study_Hours'], marker = 'o')
plt.title('Study Hours Over Days')
plt.xlabel('Days')
plt.ylabel('Study Hours')
plt.show()

# %%
# Advanced Line Chart

plt.figure(figsize = (7,4))

plt.plot(df['Days'],df['Study_Hours'], marker='o',color='cyan',label='Study Hours')

plt.plot(df['Days'],df['Marks'],marker='s',color='red',label='Marks')

plt.title("Study Hours and Marks Trend")
plt.xlabel('Days')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# 2. Bar Chart (Comparision)

plt.bar(df['Days'],df['Marks'],color='Darkblue')

plt.title("Marks Comparison")
plt.xlabel('Days')
plt.ylabel('Marks')
plt.show()

# %%
plt.bar(df['Study_Hours'],df['Marks'], color = 'magenta')

plt.title("Study Hours vs Marks")
plt.xlabel('Study Hours')
plt.ylabel('Marks')
plt.show()

# %%
# Advanced Bar Graph

bars = plt.bar(df['Days'],df['Marks'],color='Black')
for bar in bars:
  y = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2,y,str(y),ha='center',va='bottom')

plt.title("Marks Comparison")
plt.xlabel('Days')
plt.ylabel('Marks')
plt.grid(axis='y')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


df = pd.DataFrame(data)

x = np.arange(len(df['Days']))
width = 0.25
plt.bar(x-width/2, df['Study_Hours'], width,label = 'Study_Hours')
plt.bar(x+width/2, df['Marks'], width,label = 'Marks')
plt.xlabel('Days')
plt.ylabel('Value')
plt.title('Study Hours and Marks Comparison')
plt.legend()
plt.show()

# %%
# 3. Histogram (Dsitribution)
# Shows how valuea are spread

data = { 'Marks': [50,60,55,70,65,75,80,85,90,45,67,72,77,82,88] }
df = pd.DataFrame(data)

plt.hist(df['Marks'], bins=3, edgecolor = 'red', alpha=0.7)
plt.title("Marks Distribution")
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = {
    'Days' : ['Mon','Tue','Wed','Thu','Fri'],
    'Study_Hours' : [2,3,6,1,3.5],
    'Marks' : [93,60,67,70,85],
    'Attendance': [60,70,65,80,75],
    'Assignments_Completed' : [1,2,1,3,2]
}
df = pd.DataFrame(data)

# 4. Scatter Plot (Relationship)
plt.scatter(df['Study_Hours'], df['Marks'])

plt.title("Study Hours vs Marks")
plt.xlabel('Study Hours')
plt.ylabel('Marks')
plt.show()

# %%
# Conditional scatter plot
# Example category

df['Result'] = ['Fail','Pass','Fail','Pass','Pass']
colors = ['magenta' if r=='Fail' else 'turquoise' for r in df['Result']]

plt.scatter(df['Study_Hours'],df['Marks'],c=colors)
plt.title("Study Hours vs Marks")
plt.xlabel('Study Hours')
plt.ylabel('Marks')
plt.show()

# %% [markdown]
# # Same graphs using Seaborn (Better Visualization)

# %%
data = {
    "Day": ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun', 'Mon', 'Tue', 'Wed'],
    "Region": ['North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    "Sales": [200, 220, 250, 270, 300, 350, 400, 280, 260, 290],
    "Profit": [20, 25, 30, 35, 50, 60, 80, 40, 38, 45],
    "Customers": [30, 35, 40, 45, 50, 65, 80, 55, 48, 52],
    "Category": ['Food', 'Clothing', 'Electronics', 'Food', 'Clothing', 'Electronics', 'Food', 'Clothing', 'Electronics', 'Food']
}
df = pd.DataFrame(data)
df
# Out:
#    Day Region  Sales  Profit  Customers     Category
# 0  Mon  North    200      20         30         Food
# 1  Tue  South    220      25         35     Clothing
# 2  Wed   East    250      30         40  Electronics
# 3  Thu   West    270      35         45         Food
# 4  Fri  North    300      50         50     Clothing
# 5  Sat  South    350      60         65  Electronics
# 6  Sun   East    400      80         80         Food
# 7  Mon   West    280      40         55     Clothing
# 8  Tue  North    260      38         48  Electronics
# 9  Wed  South    290      45         52         Food

# %%
# Line Plot

sns.lineplot(x ='Day', y='Sales', data =df, color='brown')
plt.title("Sales Over Days")
plt.xlabel('Day')
plt.ylabel('Sales')
plt.show()

# %%
# Advanced line plot

sns.lineplot(x = 'Day', y = 'Profit', data = df, hue = 'Region')
plt.title("Profit Over Days")
plt.xlabel('Day')
plt.ylabel('Profit')
plt.show()

# %%
# Bar Chart

sns.barplot(x = 'Region', y = 'Profit', data = df)
plt.title("Profit by Region")
plt.xlabel('Region')
plt.ylabel('Profit')
plt.show()
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
# Advanced Bar Chart

sns.barplot(x = 'Region', y = 'Profit', data = df, hue = 'Category')
plt.title("Profit by Region and Category")
plt.xlabel('Region')
plt.ylabel('Profit')
plt.grid(axis='y')
plt.show()

# %%
# Scatter Plot

sns.scatterplot(x = 'Customers', y = 'Profit', data = df,color='black')
plt.title("Customers vs Profit")
plt.xlabel('Customers')
plt.ylabel('Profit')
plt.show()
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
# Conditional Scatter Plot

plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df,
    x="Sales",
    y="Profit",
    hue="Category",
    style="Region",
    size="Customers",
    sizes=(50, 300),
    alpha=0.8
)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Conditional Scatter Plot: Sales vs Profit")
plt.tight_layout()
plt.show()

# %%
# Histogram

sns.histplot(df['Sales'], bins = 3, kde = True,color='violet')
plt.title("Sales Distribution")
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()
